# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %%
# load csv file
df = pd.read_csv('metrics.csv')
df
# Out:
#     epoch  loss_step  step
# 0       0   0.620892    49
# 1       0   0.542996    99
# 2       0   0.547483   149
# 3       0   0.542104   199
# 4       0   0.546571   249
# ..    ...        ...   ...
# 69      0   0.312132  3499
# 70      0   0.318544  3549
# 71      0   0.342433  3599
# 72      0   0.311036  3649
# 73      0   0.322702  3699
#
# [74 rows x 3 columns]

# %%
plt.plot(df["step"], df["loss_step"], label="train loss")
plt.show()
