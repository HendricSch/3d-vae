# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %%
# load csv file
df_1 = pd.read_csv('metrics.csv')
df_3 = pd.read_csv('metrics3.csv')
df_4 = pd.read_csv('metrics4.csv')
df_5 = pd.read_csv('metrics_f16.csv')
df_5
# Out:
#      epoch  loss_step  step
# 0        0   0.831737    49
# 1        0   0.724100    99
# 2        0   0.663866   149
# 3        0   0.567663   199
# 4        0   0.549672   249
# ..     ...        ...   ...
# 119      0   0.312083  5999
# 120      0   0.313604  6049
# 121      0   0.316780  6099
# 122      0   0.296942  6149
# 123      0   0.294340  6199
#
# [124 rows x 3 columns]

# %%
# plt.plot(df_1["step"], df_1["loss_step"], label="loss 1")
# plt.plot(df_2["step"], df_2["loss_step"], label="loss 2")
plt.plot(df_3["step"], df_3["loss_step"], label="learning rate = 1e-4, f8, no attention")
plt.plot(df_4["step"] + 22749, df_4["loss_step"], label="learning rate = 4.5e-6, f8, no attention")
plt.plot(df_5["step"], df_5["loss_step"], label="learning rate = 4.5e-6, f16, attention")
plt.xlabel("step")
plt.ylabel("L1 loss + KL divergence")
plt.legend()
plt.show()
