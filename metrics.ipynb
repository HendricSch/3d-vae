# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %%
# load csv file
df_1 = pd.read_csv('metrics.csv')
df_2 = pd.read_csv('metrics2.csv')
df_3 = pd.read_csv('metrics3.csv')
df_4 = pd.read_csv('metrics4.csv')
df_1
# Out:
#     epoch  loss_step  step
# 0       0   0.620892    49
# 1       0   0.542996    99
# 2       0   0.547483   149
# 3       0   0.542104   199
# 4       0   0.546571   249
# ..    ...        ...   ...
# 69      0   0.312132  3499
# 70      0   0.318544  3549
# 71      0   0.342433  3599
# 72      0   0.311036  3649
# 73      0   0.322702  3699
#
# [74 rows x 3 columns]

# %%
# plt.plot(df_1["step"], df_1["loss_step"], label="loss 1")
# plt.plot(df_2["step"], df_2["loss_step"], label="loss 2")
plt.plot(df_3["step"], df_3["loss_step"], label="learning rate = 1e-4")
plt.plot(df_4["step"] + 22749, df_4["loss_step"], label="learning rate = 4.5e-6")
plt.xlabel("step")
plt.ylabel("L1 loss + KL divergence") 
plt.legend()
plt.show()
